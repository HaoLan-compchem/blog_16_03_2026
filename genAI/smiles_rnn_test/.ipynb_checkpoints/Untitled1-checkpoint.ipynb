# %%
# %load_ext tensorboard

# %%
# !python train_prior.py -i all_unique_processed_dataset.smi -o smiles_rnn_test -s

# %%
# %tensorboard --bind_all --logdir tb_train_prior
# Out:
#       <iframe id="tensorboard-frame-b7b65ce16e74e7d3" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b7b65ce16e74e7d3");
#           const url = new URL("/", window.location);
#           const port = 6010;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
